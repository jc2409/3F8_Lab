# %% [markdown]
# <a href="https://colab.research.google.com/github/jc2409/3F8_Lab/blob/main/3F8_coursework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3F8 Inference: Coursework
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cbl-cambridge/3F8-Lab/blob/main/coursework.ipynb)
#
# This is the auxiliary code for the 3F8 coursework. Some parts are missing and should be completed by the student. These are marked with `XXX`.

# %% [markdown]
# ## How to Use This Notebook
#
# This notebook is divided into **cells** containing either code or text. To work through the coursework, run each code cell from top to bottom using these keyboard shortcuts:
#
# - **Shift+Enter** — Run the current cell and move to the next one
# - **Ctrl+Enter** — Run the current cell and stay on it (useful for re-running a cell after changing a parameter)
#
# Cells can be run in any order, but each cell may depend on variables or functions defined in earlier cells. When working through the notebook for the first time, it is simplest to run cells from top to bottom. If you go back and change a cell, make sure to re-run it and any later cells that depend on it.
#
# You can use the **+ Code** / **+ Text** buttons that appear below each cell when you hover to add a new cell (useful for experimenting or adding your own notes).

# %% [markdown]
# ## Setup
#
# The coursework requires two data files: `X.txt` and `y.txt`.
#
# **Option 1 (recommended):** Run the cell below to download them automatically from GitHub.

# %%
import urllib.request

base_url = "https://raw.githubusercontent.com/cbl-cambridge/3F8-Lab/main/"
for filename in ["X.txt", "y.txt"]:
    urllib.request.urlretrieve(base_url + filename, filename)
    print(f"Downloaded {filename}")
# Out:
# Downloaded X.txt
# Downloaded y.txt

# %% [markdown]
# **Option 2:** Upload the files manually. In Google Colab:
# 1. Click the **files icon** (folder) in the left sidebar
# 2. Click the **upload icon** at the top of the file browser
# 3. Select `X.txt` and `y.txt` from your computer
#
# <img src="https://raw.githubusercontent.com/cbl-cambridge/3F8-Lab/main/Colab%20Upload%20Instructions.png" width="300">

# %% [markdown]
# ## Load and Visualise the Data

# %%
# We load the data

import numpy as np

X = np.loadtxt('X.txt')
y = np.loadtxt('y.txt')

# %%
# We randomly permute the data

np.random.seed(42)
permutation = np.random.permutation(X.shape[ 0 ])
X = X[ permutation, : ]
y = y[ permutation ]

# %%
# We plot the data

import matplotlib.pyplot as plt

def plot_data_internal(X, y):
    x_min, x_max = X[ :, 0 ].min() - .5, X[ :, 0 ].max() + .5
    y_min, y_max = X[ :, 1 ].min() - .5, X[ :, 1 ].max() + .5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))
    plt.figure()
    plt.xlim(xx.min(None), xx.max(None))
    plt.ylim(yy.min(None), yy.max(None))
    ax = plt.gca()
    ax.plot(X[y == 0, 0], X[y == 0, 1], 'ro', label = 'Class 1')
    ax.plot(X[y == 1, 0], X[y == 1, 1], 'bo', label = 'Class 2')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.title('Plot data')
    plt.legend(loc = 'upper left', scatterpoints = 1, numpoints = 1)
    return xx, yy

def plot_data(X, y, filename=None):
    xx, yy = plot_data_internal(X, y)
    if filename:
        plt.savefig(filename, dpi=100, bbox_inches='tight')
    plt.show()

# %%
plot_data(X, y, filename='fig_data.png')

# %% [markdown]
# ## Train/Test Split and Model Functions

# %%
# We split the data into train and test sets

n_train = 800
X_train = X[ 0 : n_train, : ]
X_test = X[ n_train :, : ]
y_train = y[ 0 : n_train ]
y_test = y[ n_train : ]

# %%
# The logistic function

def logistic(x): return 1.0 / (1.0 + np.exp(-x))

##
# Function that makes predictions with a logistic classifier
#
# Input:
#
# X_tile: matrix of input features (with a constant 1 appended to the left)
#         for which to make predictions
# w: vector of model parameters
#
# Output: The predictions of the logistic classifier
#

def predict(X_tilde, w): return logistic(np.dot(X_tilde, w))

##
# Function that computes the average loglikelihood of the logistic classifier on some data.
#
# Input:
#
# X_tile: matrix of input features (with a constant 1 appended to the left)
#         for which to make predictions
# y: vector of binary output labels
# w: vector of model parameters
#
# Output: The average loglikelihood
#

def compute_average_ll(X_tilde, y, w):
    output_prob = predict(X_tilde, w)
    return np.mean(y * np.log(output_prob) + (1 - y) * np.log(1.0 - output_prob))

##
# Function that expands a matrix of input features by adding a column equal to 1.
#
# Input:
#
# X: matrix of input features.
#
# Output: Matrix x_tilde with one additional constant column equal to 1 added.
#

def get_x_tilde(X): return np.concatenate((np.ones((X.shape[ 0 ], 1 )), X), 1)

# %% [markdown]
# ## Training the Logistic Classifier

# %%
##
# Function that finds the model parameters by optimising the likelihood using gradient descent
#
def fit_w(X_tilde_train, y_train, X_tilde_test, y_test, n_steps, alpha, verbose=True):
    w = np.random.randn(X_tilde_train.shape[ 1 ])
    ll_train = np.zeros(n_steps)
    ll_test = np.zeros(n_steps)
    for i in range(n_steps):
        sigmoid_value = predict(X_tilde_train, w)
        w = w + alpha * np.dot((y_train - sigmoid_value), X_tilde_train)
        ll_train[ i ] = compute_average_ll(X_tilde_train, y_train, w)
        ll_test[ i ] = compute_average_ll(X_tilde_test, y_test, w)
        if verbose:
            print(ll_train[ i ], ll_test[ i ])
    return w, ll_train, ll_test

# %%
# We train the linear classifier

alpha = 1/800
n_steps = 100

X_tilde_train_lin = get_x_tilde(X_train)
X_tilde_test_lin = get_x_tilde(X_test)
w_lin, ll_train_lin, ll_test_lin = fit_w(X_tilde_train_lin, y_train, X_tilde_test_lin, y_test, n_steps, alpha, verbose=False)
print(f"Linear — final train LL: {ll_train_lin[-1]:.6f},  test LL: {ll_test_lin[-1]:.6f}")
# Out:
# Linear — final train LL: -0.622540,  test LL: -0.629442

# %% [markdown]
# ## Plotting the Results

# %%
def plot_ll(ll, filename=None):
    plt.figure()
    ax = plt.gca()
    plt.xlim(0, len(ll) + 2)
    plt.ylim(min(ll) - 0.1, max(ll) + 0.1)
    ax.plot(np.arange(1, len(ll) + 1), ll, 'r-')
    plt.xlabel('Steps')
    plt.ylabel('Average log-likelihood')
    plt.title('Plot Average Log-likelihood Curve')
    if filename:
        plt.savefig(filename, dpi=100, bbox_inches='tight')
    plt.show()

# %%
# Plot and save training and test log likelihoods for linear classifier
plot_ll(ll_train_lin, filename='fig_lin_ll_train.png')
plot_ll(ll_test_lin,  filename='fig_lin_ll_test.png')

# %%
def plot_predictive_distribution(X, y, w, map_inputs=lambda x: x, filename=None):
    xx, yy = plot_data_internal(X, y)
    ax = plt.gca()
    X_tilde = get_x_tilde(map_inputs(np.concatenate(
        (xx.ravel().reshape((-1, 1)), yy.ravel().reshape((-1, 1))), 1)))
    Z = predict(X_tilde, w)
    Z = Z.reshape(xx.shape)
    cs2 = ax.contour(xx, yy, Z, cmap='RdBu', linewidths=2)
    plt.clabel(cs2, fmt='%2.1f', colors='k', fontsize=14)
    if filename:
        plt.savefig(filename, dpi=100, bbox_inches='tight')
    plt.show()

# %%
# Plot and save predictive distribution for linear classifier
plot_predictive_distribution(X, y, w_lin, filename='fig_lin_contour.png')

# %%
# Confusion matrix for linear classifier (Exercise e)
threshold = 0.5
y_pred_test_lin = (predict(X_tilde_test_lin, w_lin) > threshold).astype(int)

n0_test = np.sum(y_test == 0)
n1_test = np.sum(y_test == 1)

TN_lin = np.sum((y_test == 0) & (y_pred_test_lin == 0)) / n0_test
FP_lin = np.sum((y_test == 0) & (y_pred_test_lin == 1)) / n0_test
FN_lin = np.sum((y_test == 1) & (y_pred_test_lin == 0)) / n1_test
TP_lin = np.sum((y_test == 1) & (y_pred_test_lin == 1)) / n1_test

print("=== Linear Classifier Results (Exercise e) ===")
print(f"Final avg train LL : {ll_train_lin[-1]:.6f}")
print(f"Final avg test  LL : {ll_test_lin[-1]:.6f}")
print("Confusion matrix (test set):")
print(f"  P(yhat=0|y=0) = {TN_lin:.4f}   P(yhat=1|y=0) = {FP_lin:.4f}")
print(f"  P(yhat=0|y=1) = {FN_lin:.4f}   P(yhat=1|y=1) = {TP_lin:.4f}")
# Out:
# === Linear Classifier Results (Exercise e) ===
# Final avg train LL : -0.622540
# Final avg test  LL : -0.629442
# Confusion matrix (test set):
#   P(yhat=0|y=0) = 0.6818   P(yhat=1|y=0) = 0.3182
#   P(yhat=0|y=1) = 0.2444   P(yhat=1|y=1) = 0.7556

# %% [markdown]
# ## Non-Linear Feature Expansion with Radial Basis Functions

# %%
##
# Function that replaces initial input features by evaluating Gaussian basis functions
# on a grid of points
#
# Inputs:
#
# l: hyper-parameter for the width of the Gaussian basis functions
# Z: location of the Gaussian basis functions
# X: points at which to evaluate the basis functions
#
# Output: Feature matrix with the evaluations of the Gaussian basis functions.
#

def evaluate_basis_functions(l, X, Z):
    X2 = np.sum(X**2, 1)
    Z2 = np.sum(Z**2, 1)
    ones_Z = np.ones(Z.shape[ 0 ])
    ones_X = np.ones(X.shape[ 0 ])
    r2 = np.outer(X2, ones_Z) - 2 * np.dot(X, Z.T) + np.outer(ones_X, Z2)
    return np.exp(-0.5 / l**2 * r2)

# %%
# We expand the data

l = 0.8 # XXX Width of the Gaussian basis funcction. To be completed by the student

X_tilde_train = get_x_tilde(evaluate_basis_functions(l, X_train, X_train))
X_tilde_test = get_x_tilde(evaluate_basis_functions(l, X_test, X_train))

# %%
# We train the new classifier on the feature expanded inputs

alpha = 0.28/800 # XXX Learning rate for gradient-based optimisation with basis functions. To be completed by the student
n_steps = 3000 # XXX Number of steps of gradient-based optimisation with basis functions. To be completed by the student

w, ll_train, ll_test = fit_w(X_tilde_train, y_train, X_tilde_test, y_test, n_steps, alpha)
# Out:
# -1.8769415792758384 -1.8206584410026616
# -1.5740135595975924 -1.5079279304606448
# -1.3631695348961412 -1.288929922639373
# -1.2262450729810812 -1.1619906604641712
# -1.122452517768292 -1.0684663827297742
# -1.0337663699657673 -0.9891795644561197
# -0.9551301774794176 -0.9144617895228445
# -0.8853602928213161 -0.8521349805537253
# -0.8242945706434598 -0.7894642371244106
# -0.7724495319141076 -0.7517017450106982
# -0.7313811044948477 -0.6944177424550227
# -0.7096945130086048 -0.7145536489287312
# -0.7212639670891008 -0.6564823595173881
# -0.8272178237415773 -0.8954832483080665
# -0.867243313867216 -0.7316304860338373
# -1.0263350464288759 -1.146749709335962
# -0.797326578582007 -0.6459509392106539
# -0.876416021036257 -0.981736916049399
# -0.7431173338426746 -0.5979799857060414
# -0.8098149397337123 -0.9165731993882386
# -0.7121691096415167 -0.5676082310954198
# -0.7652816940562255 -0.8751173513700117
# -0.679725580003766 -0.5374888760670409
# -0.7153148158963489 -0.8250947910499505
# ...

# %%
# We plot the training and test log likelihoods

plot_ll(ll_train)
plot_ll(ll_test)

# %%
# We plot the predictive distribution

plot_predictive_distribution(X, y, w, lambda x : evaluate_basis_functions(l, x, X_train))

# %% [markdown]
# ## RBF Experiments: l = 0.01, 0.1, 1

# %%
# RBF feature expansion: l = 0.01
l_001 = 0.01
X_tilde_train_001 = get_x_tilde(evaluate_basis_functions(l_001, X_train, X_train))
X_tilde_test_001  = get_x_tilde(evaluate_basis_functions(l_001, X_test,  X_train))

# %%
# Train RBF classifier: l = 0.01
alpha_001  = 0.01 / 800
n_steps_001 = 1000
w_001, ll_train_001, ll_test_001 = fit_w(
    X_tilde_train_001, y_train, X_tilde_test_001, y_test,
    n_steps_001, alpha_001, verbose=False)
print(f"l=0.01 — final train LL: {ll_train_001[-1]:.6f},  test LL: {ll_test_001[-1]:.6f}")
# Out:
# l=0.01 — final train LL: -0.795667,  test LL: -0.700312

# %%
# Plot LL curves: l = 0.01
plot_ll(ll_train_001, filename='fig_rbf001_ll_train.png')
plot_ll(ll_test_001,  filename='fig_rbf001_ll_test.png')
plot_predictive_distribution(X, y, w_001,
    map_inputs=lambda x: evaluate_basis_functions(l_001, x, X_train),
    filename='fig_rbf001_contour.png')

# %%
# Confusion matrix: l = 0.01
y_pred_001 = (predict(X_tilde_test_001, w_001) > 0.5).astype(int)
TN_001 = np.sum((y_test == 0) & (y_pred_001 == 0)) / n0_test
FP_001 = np.sum((y_test == 0) & (y_pred_001 == 1)) / n0_test
FN_001 = np.sum((y_test == 1) & (y_pred_001 == 0)) / n1_test
TP_001 = np.sum((y_test == 1) & (y_pred_001 == 1)) / n1_test
print("=== RBF l=0.01 Confusion Matrix (test set) ===")
print(f"  P(yhat=0|y=0) = {TN_001:.4f}   P(yhat=1|y=0) = {FP_001:.4f}")
print(f"  P(yhat=0|y=1) = {FN_001:.4f}   P(yhat=1|y=1) = {TP_001:.4f}")
# Out:
# === RBF l=0.01 Confusion Matrix (test set) ===
#   P(yhat=0|y=0) = 0.0364   P(yhat=1|y=0) = 0.9636
#   P(yhat=0|y=1) = 0.1333   P(yhat=1|y=1) = 0.8667

# %%
# RBF feature expansion: l = 0.1
l_01 = 0.1
X_tilde_train_01 = get_x_tilde(evaluate_basis_functions(l_01, X_train, X_train))
X_tilde_test_01  = get_x_tilde(evaluate_basis_functions(l_01, X_test,  X_train))

# %%
# Train RBF classifier: l = 0.1
alpha_01   = 0.1 / 800
n_steps_01 = 1000
w_01, ll_train_01, ll_test_01 = fit_w(
    X_tilde_train_01, y_train, X_tilde_test_01, y_test,
    n_steps_01, alpha_01, verbose=False)
print(f"l=0.1 — final train LL: {ll_train_01[-1]:.6f},  test LL: {ll_test_01[-1]:.6f}")
# Out:
# l=0.1 — final train LL: -0.459730,  test LL: -0.418676

# %%
# Plot LL curves: l = 0.1
plot_ll(ll_train_01, filename='fig_rbf01_ll_train.png')
plot_ll(ll_test_01,  filename='fig_rbf01_ll_test.png')
plot_predictive_distribution(X, y, w_01,
    map_inputs=lambda x: evaluate_basis_functions(l_01, x, X_train),
    filename='fig_rbf01_contour.png')

# %%
# Confusion matrix: l = 0.1
y_pred_01 = (predict(X_tilde_test_01, w_01) > 0.5).astype(int)
TN_01 = np.sum((y_test == 0) & (y_pred_01 == 0)) / n0_test
FP_01 = np.sum((y_test == 0) & (y_pred_01 == 1)) / n0_test
FN_01 = np.sum((y_test == 1) & (y_pred_01 == 0)) / n1_test
TP_01 = np.sum((y_test == 1) & (y_pred_01 == 1)) / n1_test
print("=== RBF l=0.1 Confusion Matrix (test set) ===")
print(f"  P(yhat=0|y=0) = {TN_01:.4f}   P(yhat=1|y=0) = {FP_01:.4f}")
print(f"  P(yhat=0|y=1) = {FN_01:.4f}   P(yhat=1|y=1) = {TP_01:.4f}")
# Out:
# === RBF l=0.1 Confusion Matrix (test set) ===
#   P(yhat=0|y=0) = 0.8182   P(yhat=1|y=0) = 0.1818
#   P(yhat=0|y=1) = 0.1778   P(yhat=1|y=1) = 0.8222

# %%
# RBF feature expansion: l = 1
l_1 = 1.0
X_tilde_train_1 = get_x_tilde(evaluate_basis_functions(l_1, X_train, X_train))
X_tilde_test_1  = get_x_tilde(evaluate_basis_functions(l_1, X_test,  X_train))

# %%
# Train RBF classifier: l = 1
alpha_1   = 0.5 / 800
n_steps_1 = 500
w_1, ll_train_1, ll_test_1 = fit_w(
    X_tilde_train_1, y_train, X_tilde_test_1, y_test,
    n_steps_1, alpha_1, verbose=False)
print(f"l=1 — final train LL: {ll_train_1[-1]:.6f},  test LL: {ll_test_1[-1]:.6f}")
# Out:
# l=1 — final train LL: -0.320307,  test LL: -0.497073

# %%
# Plot LL curves: l = 1
plot_ll(ll_train_1, filename='fig_rbf1_ll_train.png')
plot_ll(ll_test_1,  filename='fig_rbf1_ll_test.png')
plot_predictive_distribution(X, y, w_1,
    map_inputs=lambda x: evaluate_basis_functions(l_1, x, X_train),
    filename='fig_rbf1_contour.png')

# %%
# Confusion matrix: l = 1
y_pred_1 = (predict(X_tilde_test_1, w_1) > 0.5).astype(int)
TN_1 = np.sum((y_test == 0) & (y_pred_1 == 0)) / n0_test
FP_1 = np.sum((y_test == 0) & (y_pred_1 == 1)) / n0_test
FN_1 = np.sum((y_test == 1) & (y_pred_1 == 0)) / n1_test
TP_1 = np.sum((y_test == 1) & (y_pred_1 == 1)) / n1_test
print("=== RBF l=1 Confusion Matrix (test set) ===")
print(f"  P(yhat=0|y=0) = {TN_1:.4f}   P(yhat=1|y=0) = {FP_1:.4f}")
print(f"  P(yhat=0|y=1) = {FN_1:.4f}   P(yhat=1|y=1) = {TP_1:.4f}")
# Out:
# === RBF l=1 Confusion Matrix (test set) ===
#   P(yhat=0|y=0) = 0.8091   P(yhat=1|y=0) = 0.1909
#   P(yhat=0|y=1) = 0.0222   P(yhat=1|y=1) = 0.9778

# %% [markdown]
# ## Download All Figures

# %%
# Zip all saved figures and download (Google Colab)
import zipfile, os

figure_files = [
    'fig_data.png',
    'fig_lin_ll_train.png', 'fig_lin_ll_test.png', 'fig_lin_contour.png',
    'fig_rbf001_ll_train.png', 'fig_rbf001_ll_test.png', 'fig_rbf001_contour.png',
    'fig_rbf01_ll_train.png',  'fig_rbf01_ll_test.png',  'fig_rbf01_contour.png',
    'fig_rbf1_ll_train.png',   'fig_rbf1_ll_test.png',   'fig_rbf1_contour.png',
]

with zipfile.ZipFile('3F8_figures.zip', 'w') as zf:
    for f in figure_files:
        if os.path.exists(f):
            zf.write(f)
            print(f"Added {f}")
        else:
            print(f"WARNING: {f} not found!")

try:
    from google.colab import files
    files.download('3F8_figures.zip')
except ImportError:
    print('Not running in Colab — figures saved locally.')
    print('Zip file: 3F8_figures.zip')
# Out:
# Added fig_data.png
# Added fig_lin_ll_train.png
# Added fig_lin_ll_test.png
# Added fig_lin_contour.png
# Added fig_rbf001_ll_train.png
# Added fig_rbf001_ll_test.png
# Added fig_rbf001_contour.png
# Added fig_rbf01_ll_train.png
# Added fig_rbf01_ll_test.png
# Added fig_rbf01_contour.png
# Added fig_rbf1_ll_train.png
# Added fig_rbf1_ll_test.png
# Added fig_rbf1_contour.png
